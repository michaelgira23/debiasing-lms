# %%
from google.colab import drive
try:
  drive.mount('/content/drive')
except:
  pass
# %cd /content/drive/My Drive/unprejudiced

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)

# %%
# install as colab doesn't have transformers in default
# !pip install transformers
# !pip install colorama

# %%
import sys
sys.path.append("./StereoSet/code")
sys.path.append("./StereoSet")

# %%
# !python ./training_lr.py \
        --device 'cuda' \
        --num_epoches 15 \
        --batch_size 100 \
        --lr 0.001 \
        --input_max_dim 50 \
        --model_save_path 'trained_models/gpt2/ln_unfrozen/in_out_net_varied_lr/' \
        --gpt2_name 'gpt2' \
        --freeze_pos \
        --freeze_ff \
        --freeze_attn \
        --freeze_wte \
        --eval_stereoset \
        --write_stereoset \
        --in_net \
        --in_net_init_identity \
        --out_net \
        --out_net_init_identity \
        # --freeze_ln \
        # --load_pretrained_model \
        # --model_load_path 'trained_models/model_indim50_lr001_noln_outnet_bz100_gptmedium.pth' \      
        # --dup_lm_head_bias False \
        # --dup_lm_head False \
